# %% [markdown]
# <a href="https://colab.research.google.com/github/Shohjahon02/first_my_git/blob/main/JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets.git
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 43 (delta 43), pack-reused 93
# Receiving objects: 100% (145/145), 9.72 MiB | 11.85 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
import json

x = 10
x_json = json.dumps(x)

ism = "anvar"
ism_json = json.dumps(ism)

sonlar = [12, 45, 23, 67]
sonlar_json = json.dumps(sonlar)

# %%
sonlar_json
# Out:
# '[12, 45, 23, 67]'

# %%
bemor = {
  "ism": "Alijon Valiyev",
  "yosh": 30,
  "oila": True,
  "farzandlar": ("Ahmad","Bonu"),
  "allergiya": None,
  "dorilar": [
    {"nomi": "Analgin", "miqdori": 0.5},
    {"nomi": "Panadol", "miqdori": 1.2}
  ]
}

bemor_json = json.dumps(bemor)

# %%
bemor_json
# Out:
# '{"ism": "Alijon Valiyev", "yosh": 30, "oila": true, "farzandlar": ["Ahmad", "Bonu"], "allergiya": null, "dorilar": [{"nomi": "Analgin", "miqdori": 0.5}, {"nomi": "Panadol", "miqdori": 1.2}]}'

# %%
print(bemor_json)
# Out:
# {"ism": "Alijon Valiyev", "yosh": 30, "oila": true, "farzandlar": ["Ahmad", "Bonu"], "allergiya": null, "dorilar": [{"nomi": "Analgin", "miqdori": 0.5}, {"nomi": "Panadol", "miqdori": 1.2}]}

# %%
bemor_json = json.dumps(bemor, indent=4)
print(bemor_json)
# Out:
# {
#     "ism": "Alijon Valiyev",
#     "yosh": 30,
#     "oila": true,
#     "farzandlar": [
#         "Ahmad",
#         "Bonu"
#     ],
#     "allergiya": null,
#     "dorilar": [
#         {
#             "nomi": "Analgin",
#             "miqdori": 0.5
#         },
#         {
#             "nomi": "Panadol",
#             "miqdori": 1.2
#         }
#     ]
# }

# %%
import requests, json
r = requests.get('http://api.nobelprize.org/v1/laureate.json')
data = r.json()
# data['laureates']
pd.DataFrame(data['laureates'],)
# Out:
#        id                   firstname    surname        born        died  \
# 0       1              Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1       2                  Hendrik A.    Lorentz  1853-07-18  1928-02-04
# 2       3                      Pieter     Zeeman  1865-05-25  1943-10-09
# 3       4                       Henri  Becquerel  1852-12-15  1908-08-25
# 4       5                      Pierre      Curie  1859-05-15  1906-04-19
# ..    ...                         ...        ...         ...         ...
# 976  1019                    Memorial        NaN  1987-00-00  0000-00-00
# 977  1020  Center for Civil Liberties        NaN  2007-00-00  0000-00-00
# 978  1021                         Ben   Bernanke  1953-12-13  0000-00-00
# 979  1022                     Douglas    Diamond  1953-10-25  0000-00-00
# 980  1023                      Philip     Dybvig  1955-05-22  0000-00-00
#
#                bornCountry bornCountryCode                bornCity  \
# ...

# %%
r = requests.get("https://openlibrary.org/subjects/python.json?published_in=2015-2021")
pd.DataFrame(r.json()['works'])
# Out:
#                    key                                              title  \
# 0   /works/OL17795703W                          Python for bioinformatics
# 1    /works/OL6045694W                               Python in a Nutshell
# 2   /works/OL23330617W                        Making music with computers
# 3   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 4   /works/OL21703042W                               Tour of Data Science
# 5   /works/OL19548251W                                Python for Everyone
# 6   /works/OL14940051W            Natural Language Processing With Python
# 7   /works/OL25217001W                 Introduction to Python Programming
# 8   /works/OL19932156W                                      Fluent Python
# 9   /works/OL25187574W  Introduction to Modeling and Simulation with M...
# 10  /works/OL17308344W                           Web Scraping with Python
# 11  /works/OL25347363W                      Survival Analysis with Python
#
# ...

# %%
r.json()
# Out:
# {'key': '/subjects/python',
#  'name': 'python',
#  'subject_type': 'subject',
#  'work_count': 69,
#  'works': [{'key': '/works/OL17795703W',
#    'title': 'Python for bioinformatics',
#    'edition_count': 10,
#    'cover_id': 8078288,
#    'cover_edition_key': 'OL26385029M',
#    'subject': ['Bioinformatics',
#     'Python (computer program language)',
#     'Python (Computer program language)',
#     'Computational Biology',
#     'Bio-informatique',
#     'Python (Langage de programmation)',
#     'Programming languages (Electronic computers)',
#     'Programming Languages',
#     'Langages de programmation',
#     'COMPUTERS',
#     'Python',
#     'NATURE',
#     'Reference',
#     'SCIENCE',
#     'Life Sciences',
#     'Biology',
#     'General'],
#    'ia_collection': [''],
#    'lendinglibrary': False,
#    'printdisabled': False,
#    'lending_edition': '',
#    'lending_identifier': '',
#    'authors': [{'key': '/authors/OL3871440A', 'name': 'Sebastian Bassi'}],
# ...
