# %% [markdown]
# <a href="https://colab.research.google.com/github/Shohjahon02/first_my_git/blob/main/concat%26pivot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0
# Unpacking objects: 100% (60/60), 20.24 MiB | 4.86 MiB/s, done.

# %%
bank = pd.read_csv("/content/Practicum_Datasets/bank.csv", delimiter=';')

# %%
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
bank.shape
# Out:
# (4521, 17)

# %%
bank.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
bank1, bank2 = bank[:2521], bank[2521:]

# %%
bank1
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 1      33     services   married  secondary      no     4789     yes  yes
# 2      35   management    single   tertiary      no     1350     yes   no
# 3      30   management   married   tertiary      no     1476     yes  yes
# 4      59  blue-collar   married  secondary      no        0     yes   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 2516   30   management   married   tertiary      no     1882     yes   no
# 2517   48  blue-collar   married    unknown      no      131     yes   no
# 2518   30   technician    single  secondary      no      175      no   no
# 2519   43   technician    single   tertiary     yes        0      no   no
# 2520   38   management  divorced   tertiary      no     4425     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
bank2
# Out:
#       age            job   marital  education default  balance housing loan  \
# 2521   46     unemployed   married  secondary      no     3533     yes   no
# 2522   59    blue-collar  divorced  secondary      no     3573      no   no
# 2523   44     management  divorced   tertiary      no      476     yes  yes
# 2524   35    blue-collar   married  secondary      no     1257     yes   no
# 2525   55    blue-collar   married    unknown      no       23      no   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
# 4518   57     technician   married  secondary      no      295      no   no
# 4519   28    blue-collar   married  secondary      no     1137      no   no
# 4520   44   entrepreneur    single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.concat([bank1, bank2])
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank1, bank2, bank3 = bank[:1000], bank[1000:2000], bank[2000:]  #bank ma'lumotlar to'plamini bank1, bank2 va bank3 ga bo'lib yuborish
bank3
# Out:
#       age            job  marital  education default  balance housing loan  \
# 2000   28    blue-collar  married    primary      no       60     yes   no
# 2001   45    blue-collar  married    primary      no      137     yes  yes
# 2002   32         admin.   single   tertiary      no     1583     yes   no
# 2003   46         admin.  married  secondary      no     -121     yes  yes
# 2004   28    blue-collar   single  secondary      no     1065     yes  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.concat([bank1, bank2, bank3], axis=0)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.concat([bank1, bank2, bank3], axis=1)
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0     30.0   unemployed  married    primary      no   1787.0      no   no
# 1     33.0     services  married  secondary      no   4789.0     yes  yes
# 2     35.0   management   single   tertiary      no   1350.0     yes   no
# 3     30.0   management  married   tertiary      no   1476.0     yes  yes
# 4     59.0  blue-collar  married  secondary      no      0.0     yes   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 4516   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 4517   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 4518   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 4519   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 4520   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
#
#        contact   day  ... loan   contact   day  month  duration campaign  \
# ...

# %%
bank1 = bank1.set_index('age')

# %%
bank1
# Out:
#              job  marital  education default  balance housing loan    contact  \
# age
# 30    unemployed  married    primary      no     1787      no   no   cellular
# 33      services  married  secondary      no     4789     yes  yes   cellular
# 35    management   single   tertiary      no     1350     yes   no   cellular
# 30    management  married   tertiary      no     1476     yes  yes    unknown
# 59   blue-collar  married  secondary      no        0     yes   no    unknown
# ..           ...      ...        ...     ...      ...     ...  ...        ...
# 38   blue-collar  married  secondary      no     1370     yes   no   cellular
# 58    management  married  secondary      no       37      no   no   cellular
# 34    management   single   tertiary      no      673     yes  yes   cellular
# 40      services  married  secondary      no     -342     yes   no    unknown
# 20       student   single  secondary      no      291      no   no  telephone
#
# ...

# %%
bank2 = bank2.set_index('age')

# %%
pd.concat([bank1, bank2], axis=1)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-25-b8e4f3bc34d5> in <module>
# ----> 1 pd.concat([bank1, bank2], axis=1)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     358     )
#     359
# --> 360     return op.get_result()
#     361
#     362
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     589                     obj_labels = obj.axes[1 - ax]
#     590                     if not new_labels.equals(obj_labels):
# ...

# %%
data = pd.read_csv('/content/Practicum_Datasets/data_pivot.csv')
data
# Out:
#                               date     item      value
# 0    1959-03-31 23:59:59.999999999  realgdp   2710.349
# 1    1959-03-31 23:59:59.999999999     infl      0.000
# 2    1959-03-31 23:59:59.999999999    unemp      5.800
# 3    1959-06-30 23:59:59.999999999  realgdp   2778.801
# 4    1959-06-30 23:59:59.999999999     infl      2.340
# ..                             ...      ...        ...
# 604  2009-06-30 23:59:59.999999999     infl      3.370
# 605  2009-06-30 23:59:59.999999999    unemp      9.200
# 606  2009-09-30 23:59:59.999999999  realgdp  12990.341
# 607  2009-09-30 23:59:59.999999999     infl      3.560
# 608  2009-09-30 23:59:59.999999999    unemp      9.600
#
# [609 rows x 3 columns]

# %%
pivoted_data = data.pivot('date', 'item', 'value') 
pivoted_data
# Out:
# item                           infl    realgdp  unemp
# date
# 1959-03-31 23:59:59.999999999  0.00   2710.349    5.8
# 1959-06-30 23:59:59.999999999  2.34   2778.801    5.1
# 1959-09-30 23:59:59.999999999  2.74   2775.488    5.3
# 1959-12-31 23:59:59.999999999  0.27   2785.204    5.6
# 1960-03-31 23:59:59.999999999  2.31   2847.699    5.2
# ...                             ...        ...    ...
# 2008-09-30 23:59:59.999999999 -3.16  13324.600    6.0
# 2008-12-31 23:59:59.999999999 -8.79  13141.920    6.9
# 2009-03-31 23:59:59.999999999  0.94  12925.410    8.1
# 2009-06-30 23:59:59.999999999  3.37  12901.504    9.2
# 2009-09-30 23:59:59.999999999  3.56  12990.341    9.6
#
# [203 rows x 3 columns]

# %%
data['value2'] = np.random.randn(len(data))
data
# Out:
#                               date     item      value    value2
# 0    1959-03-31 23:59:59.999999999  realgdp   2710.349 -1.333095
# 1    1959-03-31 23:59:59.999999999     infl      0.000 -1.001181
# 2    1959-03-31 23:59:59.999999999    unemp      5.800 -1.022599
# 3    1959-06-30 23:59:59.999999999  realgdp   2778.801 -0.034008
# 4    1959-06-30 23:59:59.999999999     infl      2.340  0.155383
# ..                             ...      ...        ...       ...
# 604  2009-06-30 23:59:59.999999999     infl      3.370 -0.245024
# 605  2009-06-30 23:59:59.999999999    unemp      9.200  1.365494
# 606  2009-09-30 23:59:59.999999999  realgdp  12990.341 -1.515582
# 607  2009-09-30 23:59:59.999999999     infl      3.560 -0.457901
# 608  2009-09-30 23:59:59.999999999    unemp      9.600 -0.614293
#
# [609 rows x 4 columns]

# %%
pivoted_data = data.pivot('date', 'item')
pivoted_data
# Out:
#                               value                     value2            \
# item                           infl    realgdp unemp      infl   realgdp
# date
# 1959-03-31 23:59:59.999999999  0.00   2710.349   5.8 -1.001181 -1.333095
# 1959-06-30 23:59:59.999999999  2.34   2778.801   5.1  0.155383 -0.034008
# 1959-09-30 23:59:59.999999999  2.74   2775.488   5.3  1.192516  0.259294
# 1959-12-31 23:59:59.999999999  0.27   2785.204   5.6 -0.963678  0.143618
# 1960-03-31 23:59:59.999999999  2.31   2847.699   5.2 -0.873533 -0.518688
# ...                             ...        ...   ...       ...       ...
# 2008-09-30 23:59:59.999999999 -3.16  13324.600   6.0  0.038986 -1.321582
# 2008-12-31 23:59:59.999999999 -8.79  13141.920   6.9  0.748098  0.176146
# 2009-03-31 23:59:59.999999999  0.94  12925.410   8.1  0.655141 -0.463805
# 2009-06-30 23:59:59.999999999  3.37  12901.504   9.2 -0.245024 -0.695945
# 2009-09-30 23:59:59.999999999  3.56  12990.341   9.6 -0.457901 -1.515582
#
#
# ...

# %%
pivoted_data['value'].head(10)
# Out:
# item                           infl   realgdp  unemp
# date
# 1959-03-31 23:59:59.999999999  0.00  2710.349    5.8
# 1959-06-30 23:59:59.999999999  2.34  2778.801    5.1
# 1959-09-30 23:59:59.999999999  2.74  2775.488    5.3
# 1959-12-31 23:59:59.999999999  0.27  2785.204    5.6
# 1960-03-31 23:59:59.999999999  2.31  2847.699    5.2
# 1960-06-30 23:59:59.999999999  0.14  2834.390    5.2
# 1960-09-30 23:59:59.999999999  2.70  2839.022    5.6
# 1960-12-31 23:59:59.999999999  1.21  2802.616    6.3
# 1961-03-31 23:59:59.999999999 -0.40  2819.264    6.8
# 1961-06-30 23:59:59.999999999  1.47  2872.005    7.0
