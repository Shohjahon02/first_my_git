# %% [markdown]
# <a href="https://colab.research.google.com/github/Shohjahon02/first_my_git/blob/main/scatterplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df = df[df['year']>2000]
plt.figure(figsize=(16, 6))
sns.scatterplot(data=df, x='year', y='price')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.regplot(data=df, x='year', y='price')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(data=df, x=df['mileage'], y=df['price'])
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.regplot(data=df, x=df['mileage'], y=df['price'])
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(data=df, x=df['mileage'], y=df['price'], hue='transmission')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(data=df, x=df['mileage'], y=df['price'], hue='transmission',
                style='fuelType', s=100)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(data=df, x=df['year'], y=df['price'], hue='fuelType', s=50)
plt.show()

# %%
sns.swarmplot(data=df, x=df['transmission'], y=df['price'])
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 93.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 92.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 95.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 94.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 93.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 96.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
